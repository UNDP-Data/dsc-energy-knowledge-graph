# %% [markdown]
# # Run this pipeline to update the json files for KG in '00_Current Versions' and 01_Archived Versions'

# %%
import pandas as pd
import json
import datetime
import os
import shutil

# %% [markdown]
# Read current entities and relations

# %%
with open('../03_Output/00_GPT KGs/Entities.json', "r") as file:
    data = file.read()
    entities = json.loads(data)
    file.close()

# %%
file_path = '../03_Output/00_GPT KGs/Relations_replaced.csv'
relations = pd.read_csv(file_path, delimiter=';')

# %% [markdown]
# 1. Merge the entities and relations in json objects

# %%
kg_list = []
for entity in entities:
    kg_obj = {'metadata': entity, 'knowledge graph': {}}
    records = relations.loc[relations['Subject'] == entity['Entity']]
    filtered_relations = json.loads(records.to_json(orient ='records', indent = 2))
    objects = set()
    entity_relations = []
    for rel in filtered_relations:
        obj = {}
        objects.add(rel['Object'])
        obj['Relation'] = rel['Relation']
        obj['Object'] = rel['Object']
        obj['Description'] = rel['Description']
        obj['Importance'] = rel['Importance']
        entity_relations.append(obj)
    object_lst = list(objects)
    relation_obj = {entity['Entity']: entity_relations}
    kg_obj['knowledge graph']['entities'] = object_lst
    kg_obj['knowledge graph']['relations'] = relation_obj

    kg_list.append(kg_obj)

# %% [markdown]
# 2. Update the current kg and add in archive for record

# %%
timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
kg_json = json.dumps(kg_list, indent = 2)

with open('../03_Output/01_Auto KGs/00_Current Versions/knowledge_graph.json', 'w') as file:
    file.write(kg_json)
    file.close()

with open('../03_Output/01_Auto KGs/01_Archived Versions/' + str(timestamp) + '.json', 'w') as file:
    file.write(kg_json)
    file.close()

# %%
for item in kg_list:
    name = item['metadata']['Entity']
    json_ = json.dumps(item, indent = 2)
    with open('../03_Output/01_Auto KGs/00_Current Versions/' + name + '.json', 'w') as file:
        file.write(json_)
        file.close()

# %% [markdown]
# 3. Run the below cells to push JSON files from Output/Current_Version folder to 00_API folder.

# %%
def update_files_in_API(src_dir, dest_dir):
    """
    Delete all initial files in the destination directory and then copy
    all files from the source directory to the destination directory.

    Args:
        src_dir (str): The path to the source directory.
        dest_dir (str): The path to the destination directory.

    Raises:
        FileNotFoundError: If the source directory does not exist.
    """
    # Check if the source directory exists
    if not os.path.exists(src_dir):
        raise FileNotFoundError(f"Source directory '{src_dir}' does not exist.")

    # Check if the destination directory exists, if not, create it
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
        print(f"Destination directory '{dest_dir}' created.")
    else:
        # Delete all files in the destination directory
        for file_name in os.listdir(dest_dir):
            file_path = os.path.join(dest_dir, file_name)

            # Delete only if it is a file
            if os.path.isfile(file_path):
                os.remove(file_path)
                print(f"Deleted '{file_path}'.")

    # List all files in the source directory
    files = os.listdir(src_dir)

    # Copy each file to the destination directory, replacing existing files
    for file_name in files:
        src_file = os.path.join(src_dir, file_name)
        dest_file = os.path.join(dest_dir, file_name)

        # Copy only if it is a file
        if os.path.isfile(src_file):
            shutil.copy2(src_file, dest_file)
            print(f"Copied '{src_file}' to '{dest_file}'.")

    print("All files deleted in destination and copied from source successfully.")

# Example usage
source_directory = '../03_Output/01_Auto KGs/00_Current Versions'
destination_directory = '../00_API'

update_files_in_API(source_directory, destination_directory)
# Out:
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/blue economy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/internet of energy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/decentralized energy systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Energy For Development.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/free prior and informed consent.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/technology transfer.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/multi-stakeholder partnerships.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/pumped hydro storage.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/digital twins.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/land use planning.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/reliance of fuel imports.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy infrastructure services.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/appropriate and independent oversight.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/hybrid energy storage systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/vertical funding.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/national digital strategy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/indigenous energy mapping.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/critical minerals.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/sustainable energy and dependency theory.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/.DS_Store'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/disparities in renewables investment.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy resilience.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/COP28 Targets.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy demand from urbanization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/traditional energy technologies.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/resilient energy storage systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy forecasting.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/participatory governance.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/indigenous energy sovereignty.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy data repositories.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy subsisides reform.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/ecological modernization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/gender disparities in energy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/data privacy and security.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/climate finance mechanisms.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/gas hydrates.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/data ecosystems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/least cost power development plan.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/transparency and accountability mechanisms.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/environmental impact assessments.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/water-food-energy nexus.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/remote sensing.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/climate adaptation strategies.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/project gender markers.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy project cycle.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy modeling.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy services in displacement settings.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/integrating traditional knowledge.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy market and trade organizations.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/biomass.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/cogeneration.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy entrepreneurship.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy for smallholder farmers.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/national statistical offices.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/marginalized communities.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy ministries.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/data sovereignty.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/renewable energy in water services.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/battery recycling.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/just energy transition.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/digital ecosystems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy governance.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/renewable energy certificates.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/digital literacy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/peer-to-peer lending platforms.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/data equity.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy end-use sectors.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/decarbonization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/traditional ecological knowledge.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy access for informal settlements.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/human development index.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/un agencies.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/climate change scenario analysis.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/The UNDP Sustainable Energy Hub.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy efficiency.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy and modernization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/hydrogen for development.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/AI for smart grid optimization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy and health.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/data governance frameworks.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/circular economy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/open source energy modeling tools.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/indigenous land rights.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/South-South and triangular cooperation.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/SDG7 targets.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/green job creation.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/climate-smart agriculture.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/sex-disaggregated data.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/cybersecurity policy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy scenario analysis.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/enhanced energy recovery.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy poverty alleviation.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/data sharing agreements.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy tax incentives.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/public-private partnerships.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/foundational energy infrastructure.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/The UNDP SIDS Offer.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Load forecasting and demand-side management.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/multi-level governance.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/hydroelectricity.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/liquefied natural gas.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/carbon offset programs.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/ocean thermal energy conversion.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/renewable energy agencies.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/carbon-netural fuel.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy transport systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Africa Minigrids Project.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/wind energy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/tidal power.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/green buildings.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy diplomacy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/geothermal energy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/geospatial information systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/technical capacity-building initiatives.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/innovative financing.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/electrification planning.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/community-led solutions.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/blended finance mechanisms.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Action Opportunities.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/social protection.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/solar energy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/smart grid optimization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/cultural impact assessments.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/passive solar design.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/biochar.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/digital inclusive finance.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Renewable energy for sustainable tourism.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Paris Agreement Goals.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/smart metering technologies.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/multilateral development banks.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/nationally determined contributions.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/power-to-gas systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/small island developing states.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/regional energy organizations.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/micro grids.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/concentrated solar power.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/offshore renewable energy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/women's economic empowerment.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/sovereign wealth funds.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/green bonds.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/carbon pricing.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/climate resilience funds.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/nature-based solutions.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/theory of change.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy justice.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/blockchain for energy trading.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/carbon capture and storage.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/monitoring and evaluation frameworks.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/biofuels.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/whole-of-society approach.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy democracy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/integrated resource planning.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/debt-for-nature swaps.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/heating and cooling.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/national digital transformation strategies.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/risk insurance products.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy in crisis settings.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/smart energy contracts.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/clean cooking.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/generative AI.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/digital cities.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy and development economics.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/waster-to-energy solutions.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy markets.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/time poverty.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/Solar For Health.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/gender mainstreaming.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/bioenergy.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/mobile payment systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy transition roadmaps and plans.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/electric mobility.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/stakeholder engagement mechanisms.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/battery storage.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy market liberalization policits.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/knowledge_graph.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/electrolysis.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/carbon capture and utilization.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/fossil fuel phase-out.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy regulatory frameworks.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/undp accelerator labs.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/blue carbon.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/solar home systems.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/land stewardship agerements.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/gas turbine.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/carbon neutrality.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/undp country offices.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/disaster warning networks.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy cooperatives.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/benefit-sharing agreements.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/gasification.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy data analytics.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy value chain.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/resilient infrastructure.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/community-based energy resilience programs.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy poverty indices.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/intergenerational equity.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy safety nets.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy storage.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/levelized cost of electricity.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/biodigestion.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/micro-finance.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/foundational data infrastructure.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/gender-sensitive electrification planning.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/medium small micro enterprises.json'.
# Deleted '../03_Output/01_Auto KGs/00_Current Versions/energy development practitioners.json'.
# Copied '../00_API/blue economy.json' to '../03_Output/01_Auto KGs/00_Current Versions/blue economy.json'.
# Copied '../00_API/internet of energy.json' to '../03_Output/01_Auto KGs/00_Current Versions/internet of energy.json'.
# Copied '../00_API/decentralized energy systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/decentralized energy systems.json'.
# Copied '../00_API/Energy For Development.json' to '../03_Output/01_Auto KGs/00_Current Versions/Energy For Development.json'.
# Copied '../00_API/free prior and informed consent.json' to '../03_Output/01_Auto KGs/00_Current Versions/free prior and informed consent.json'.
# Copied '../00_API/technology transfer.json' to '../03_Output/01_Auto KGs/00_Current Versions/technology transfer.json'.
# Copied '../00_API/multi-stakeholder partnerships.json' to '../03_Output/01_Auto KGs/00_Current Versions/multi-stakeholder partnerships.json'.
# Copied '../00_API/pumped hydro storage.json' to '../03_Output/01_Auto KGs/00_Current Versions/pumped hydro storage.json'.
# Copied '../00_API/digital twins.json' to '../03_Output/01_Auto KGs/00_Current Versions/digital twins.json'.
# Copied '../00_API/land use planning.json' to '../03_Output/01_Auto KGs/00_Current Versions/land use planning.json'.
# Copied '../00_API/reliance of fuel imports.json' to '../03_Output/01_Auto KGs/00_Current Versions/reliance of fuel imports.json'.
# Copied '../00_API/energy infrastructure services.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy infrastructure services.json'.
# Copied '../00_API/appropriate and independent oversight.json' to '../03_Output/01_Auto KGs/00_Current Versions/appropriate and independent oversight.json'.
# Copied '../00_API/hybrid energy storage systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/hybrid energy storage systems.json'.
# Copied '../00_API/vertical funding.json' to '../03_Output/01_Auto KGs/00_Current Versions/vertical funding.json'.
# Copied '../00_API/national digital strategy.json' to '../03_Output/01_Auto KGs/00_Current Versions/national digital strategy.json'.
# Copied '../00_API/indigenous energy mapping.json' to '../03_Output/01_Auto KGs/00_Current Versions/indigenous energy mapping.json'.
# Copied '../00_API/critical minerals.json' to '../03_Output/01_Auto KGs/00_Current Versions/critical minerals.json'.
# Copied '../00_API/sustainable energy and dependency theory.json' to '../03_Output/01_Auto KGs/00_Current Versions/sustainable energy and dependency theory.json'.
# Copied '../00_API/.DS_Store' to '../03_Output/01_Auto KGs/00_Current Versions/.DS_Store'.
# Copied '../00_API/disparities in renewables investment.json' to '../03_Output/01_Auto KGs/00_Current Versions/disparities in renewables investment.json'.
# Copied '../00_API/energy resilience.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy resilience.json'.
# Copied '../00_API/COP28 Targets.json' to '../03_Output/01_Auto KGs/00_Current Versions/COP28 Targets.json'.
# Copied '../00_API/energy demand from urbanization.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy demand from urbanization.json'.
# Copied '../00_API/traditional energy technologies.json' to '../03_Output/01_Auto KGs/00_Current Versions/traditional energy technologies.json'.
# Copied '../00_API/resilient energy storage systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/resilient energy storage systems.json'.
# Copied '../00_API/energy forecasting.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy forecasting.json'.
# Copied '../00_API/participatory governance.json' to '../03_Output/01_Auto KGs/00_Current Versions/participatory governance.json'.
# Copied '../00_API/indigenous energy sovereignty.json' to '../03_Output/01_Auto KGs/00_Current Versions/indigenous energy sovereignty.json'.
# Copied '../00_API/energy data repositories.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy data repositories.json'.
# Copied '../00_API/energy subsisides reform.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy subsisides reform.json'.
# Copied '../00_API/ecological modernization.json' to '../03_Output/01_Auto KGs/00_Current Versions/ecological modernization.json'.
# Copied '../00_API/gender disparities in energy.json' to '../03_Output/01_Auto KGs/00_Current Versions/gender disparities in energy.json'.
# Copied '../00_API/data privacy and security.json' to '../03_Output/01_Auto KGs/00_Current Versions/data privacy and security.json'.
# Copied '../00_API/climate finance mechanisms.json' to '../03_Output/01_Auto KGs/00_Current Versions/climate finance mechanisms.json'.
# Copied '../00_API/gas hydrates.json' to '../03_Output/01_Auto KGs/00_Current Versions/gas hydrates.json'.
# Copied '../00_API/data ecosystems.json' to '../03_Output/01_Auto KGs/00_Current Versions/data ecosystems.json'.
# Copied '../00_API/least cost power development plan.json' to '../03_Output/01_Auto KGs/00_Current Versions/least cost power development plan.json'.
# Copied '../00_API/transparency and accountability mechanisms.json' to '../03_Output/01_Auto KGs/00_Current Versions/transparency and accountability mechanisms.json'.
# Copied '../00_API/environmental impact assessments.json' to '../03_Output/01_Auto KGs/00_Current Versions/environmental impact assessments.json'.
# Copied '../00_API/water-food-energy nexus.json' to '../03_Output/01_Auto KGs/00_Current Versions/water-food-energy nexus.json'.
# Copied '../00_API/remote sensing.json' to '../03_Output/01_Auto KGs/00_Current Versions/remote sensing.json'.
# Copied '../00_API/climate adaptation strategies.json' to '../03_Output/01_Auto KGs/00_Current Versions/climate adaptation strategies.json'.
# Copied '../00_API/project gender markers.json' to '../03_Output/01_Auto KGs/00_Current Versions/project gender markers.json'.
# Copied '../00_API/energy project cycle.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy project cycle.json'.
# Copied '../00_API/energy modeling.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy modeling.json'.
# Copied '../00_API/energy services in displacement settings.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy services in displacement settings.json'.
# Copied '../00_API/integrating traditional knowledge.json' to '../03_Output/01_Auto KGs/00_Current Versions/integrating traditional knowledge.json'.
# Copied '../00_API/energy market and trade organizations.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy market and trade organizations.json'.
# Copied '../00_API/biomass.json' to '../03_Output/01_Auto KGs/00_Current Versions/biomass.json'.
# Copied '../00_API/cogeneration.json' to '../03_Output/01_Auto KGs/00_Current Versions/cogeneration.json'.
# Copied '../00_API/energy entrepreneurship.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy entrepreneurship.json'.
# Copied '../00_API/energy for smallholder farmers.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy for smallholder farmers.json'.
# Copied '../00_API/national statistical offices.json' to '../03_Output/01_Auto KGs/00_Current Versions/national statistical offices.json'.
# Copied '../00_API/marginalized communities.json' to '../03_Output/01_Auto KGs/00_Current Versions/marginalized communities.json'.
# Copied '../00_API/energy ministries.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy ministries.json'.
# Copied '../00_API/data sovereignty.json' to '../03_Output/01_Auto KGs/00_Current Versions/data sovereignty.json'.
# Copied '../00_API/renewable energy in water services.json' to '../03_Output/01_Auto KGs/00_Current Versions/renewable energy in water services.json'.
# Copied '../00_API/battery recycling.json' to '../03_Output/01_Auto KGs/00_Current Versions/battery recycling.json'.
# Copied '../00_API/just energy transition.json' to '../03_Output/01_Auto KGs/00_Current Versions/just energy transition.json'.
# Copied '../00_API/digital ecosystems.json' to '../03_Output/01_Auto KGs/00_Current Versions/digital ecosystems.json'.
# Copied '../00_API/energy governance.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy governance.json'.
# Copied '../00_API/renewable energy certificates.json' to '../03_Output/01_Auto KGs/00_Current Versions/renewable energy certificates.json'.
# Copied '../00_API/digital literacy.json' to '../03_Output/01_Auto KGs/00_Current Versions/digital literacy.json'.
# Copied '../00_API/peer-to-peer lending platforms.json' to '../03_Output/01_Auto KGs/00_Current Versions/peer-to-peer lending platforms.json'.
# Copied '../00_API/data equity.json' to '../03_Output/01_Auto KGs/00_Current Versions/data equity.json'.
# Copied '../00_API/energy end-use sectors.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy end-use sectors.json'.
# Copied '../00_API/decarbonization.json' to '../03_Output/01_Auto KGs/00_Current Versions/decarbonization.json'.
# Copied '../00_API/traditional ecological knowledge.json' to '../03_Output/01_Auto KGs/00_Current Versions/traditional ecological knowledge.json'.
# Copied '../00_API/energy access for informal settlements.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy access for informal settlements.json'.
# Copied '../00_API/human development index.json' to '../03_Output/01_Auto KGs/00_Current Versions/human development index.json'.
# Copied '../00_API/un agencies.json' to '../03_Output/01_Auto KGs/00_Current Versions/un agencies.json'.
# Copied '../00_API/climate change scenario analysis.json' to '../03_Output/01_Auto KGs/00_Current Versions/climate change scenario analysis.json'.
# Copied '../00_API/The UNDP Sustainable Energy Hub.json' to '../03_Output/01_Auto KGs/00_Current Versions/The UNDP Sustainable Energy Hub.json'.
# Copied '../00_API/energy efficiency.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy efficiency.json'.
# Copied '../00_API/energy and modernization.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy and modernization.json'.
# Copied '../00_API/hydrogen for development.json' to '../03_Output/01_Auto KGs/00_Current Versions/hydrogen for development.json'.
# Copied '../00_API/AI for smart grid optimization.json' to '../03_Output/01_Auto KGs/00_Current Versions/AI for smart grid optimization.json'.
# Copied '../00_API/energy and health.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy and health.json'.
# Copied '../00_API/data governance frameworks.json' to '../03_Output/01_Auto KGs/00_Current Versions/data governance frameworks.json'.
# Copied '../00_API/circular economy.json' to '../03_Output/01_Auto KGs/00_Current Versions/circular economy.json'.
# Copied '../00_API/open source energy modeling tools.json' to '../03_Output/01_Auto KGs/00_Current Versions/open source energy modeling tools.json'.
# Copied '../00_API/indigenous land rights.json' to '../03_Output/01_Auto KGs/00_Current Versions/indigenous land rights.json'.
# Copied '../00_API/South-South and triangular cooperation.json' to '../03_Output/01_Auto KGs/00_Current Versions/South-South and triangular cooperation.json'.
# Copied '../00_API/SDG7 targets.json' to '../03_Output/01_Auto KGs/00_Current Versions/SDG7 targets.json'.
# Copied '../00_API/green job creation.json' to '../03_Output/01_Auto KGs/00_Current Versions/green job creation.json'.
# Copied '../00_API/climate-smart agriculture.json' to '../03_Output/01_Auto KGs/00_Current Versions/climate-smart agriculture.json'.
# Copied '../00_API/sex-disaggregated data.json' to '../03_Output/01_Auto KGs/00_Current Versions/sex-disaggregated data.json'.
# Copied '../00_API/cybersecurity policy.json' to '../03_Output/01_Auto KGs/00_Current Versions/cybersecurity policy.json'.
# Copied '../00_API/energy scenario analysis.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy scenario analysis.json'.
# Copied '../00_API/enhanced energy recovery.json' to '../03_Output/01_Auto KGs/00_Current Versions/enhanced energy recovery.json'.
# Copied '../00_API/energy poverty alleviation.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy poverty alleviation.json'.
# Copied '../00_API/data sharing agreements.json' to '../03_Output/01_Auto KGs/00_Current Versions/data sharing agreements.json'.
# Copied '../00_API/energy tax incentives.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy tax incentives.json'.
# Copied '../00_API/public-private partnerships.json' to '../03_Output/01_Auto KGs/00_Current Versions/public-private partnerships.json'.
# Copied '../00_API/foundational energy infrastructure.json' to '../03_Output/01_Auto KGs/00_Current Versions/foundational energy infrastructure.json'.
# Copied '../00_API/The UNDP SIDS Offer.json' to '../03_Output/01_Auto KGs/00_Current Versions/The UNDP SIDS Offer.json'.
# Copied '../00_API/Load forecasting and demand-side management.json' to '../03_Output/01_Auto KGs/00_Current Versions/Load forecasting and demand-side management.json'.
# Copied '../00_API/multi-level governance.json' to '../03_Output/01_Auto KGs/00_Current Versions/multi-level governance.json'.
# Copied '../00_API/hydroelectricity.json' to '../03_Output/01_Auto KGs/00_Current Versions/hydroelectricity.json'.
# Copied '../00_API/liquefied natural gas.json' to '../03_Output/01_Auto KGs/00_Current Versions/liquefied natural gas.json'.
# Copied '../00_API/carbon offset programs.json' to '../03_Output/01_Auto KGs/00_Current Versions/carbon offset programs.json'.
# Copied '../00_API/ocean thermal energy conversion.json' to '../03_Output/01_Auto KGs/00_Current Versions/ocean thermal energy conversion.json'.
# Copied '../00_API/renewable energy agencies.json' to '../03_Output/01_Auto KGs/00_Current Versions/renewable energy agencies.json'.
# Copied '../00_API/carbon-netural fuel.json' to '../03_Output/01_Auto KGs/00_Current Versions/carbon-netural fuel.json'.
# Copied '../00_API/Africa Minigrids Project.json' to '../03_Output/01_Auto KGs/00_Current Versions/Africa Minigrids Project.json'.
# Copied '../00_API/wind energy.json' to '../03_Output/01_Auto KGs/00_Current Versions/wind energy.json'.
# Copied '../00_API/tidal power.json' to '../03_Output/01_Auto KGs/00_Current Versions/tidal power.json'.
# Copied '../00_API/green buildings.json' to '../03_Output/01_Auto KGs/00_Current Versions/green buildings.json'.
# Copied '../00_API/energy diplomacy.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy diplomacy.json'.
# Copied '../00_API/geothermal energy.json' to '../03_Output/01_Auto KGs/00_Current Versions/geothermal energy.json'.
# Copied '../00_API/geospatial information systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/geospatial information systems.json'.
# Copied '../00_API/technical capacity-building initiatives.json' to '../03_Output/01_Auto KGs/00_Current Versions/technical capacity-building initiatives.json'.
# Copied '../00_API/innovative financing.json' to '../03_Output/01_Auto KGs/00_Current Versions/innovative financing.json'.
# Copied '../00_API/electrification planning.json' to '../03_Output/01_Auto KGs/00_Current Versions/electrification planning.json'.
# Copied '../00_API/community-led solutions.json' to '../03_Output/01_Auto KGs/00_Current Versions/community-led solutions.json'.
# Copied '../00_API/blended finance mechanisms.json' to '../03_Output/01_Auto KGs/00_Current Versions/blended finance mechanisms.json'.
# Copied '../00_API/Action Opportunities.json' to '../03_Output/01_Auto KGs/00_Current Versions/Action Opportunities.json'.
# Copied '../00_API/social protection.json' to '../03_Output/01_Auto KGs/00_Current Versions/social protection.json'.
# Copied '../00_API/solar energy.json' to '../03_Output/01_Auto KGs/00_Current Versions/solar energy.json'.
# Copied '../00_API/smart grid optimization.json' to '../03_Output/01_Auto KGs/00_Current Versions/smart grid optimization.json'.
# Copied '../00_API/cultural impact assessments.json' to '../03_Output/01_Auto KGs/00_Current Versions/cultural impact assessments.json'.
# Copied '../00_API/passive solar design.json' to '../03_Output/01_Auto KGs/00_Current Versions/passive solar design.json'.
# Copied '../00_API/biochar.json' to '../03_Output/01_Auto KGs/00_Current Versions/biochar.json'.
# Copied '../00_API/digital inclusive finance.json' to '../03_Output/01_Auto KGs/00_Current Versions/digital inclusive finance.json'.
# Copied '../00_API/Renewable energy for sustainable tourism.json' to '../03_Output/01_Auto KGs/00_Current Versions/Renewable energy for sustainable tourism.json'.
# Copied '../00_API/Paris Agreement Goals.json' to '../03_Output/01_Auto KGs/00_Current Versions/Paris Agreement Goals.json'.
# Copied '../00_API/smart metering technologies.json' to '../03_Output/01_Auto KGs/00_Current Versions/smart metering technologies.json'.
# Copied '../00_API/multilateral development banks.json' to '../03_Output/01_Auto KGs/00_Current Versions/multilateral development banks.json'.
# Copied '../00_API/nationally determined contributions.json' to '../03_Output/01_Auto KGs/00_Current Versions/nationally determined contributions.json'.
# Copied '../00_API/power-to-gas systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/power-to-gas systems.json'.
# Copied '../00_API/small island developing states.json' to '../03_Output/01_Auto KGs/00_Current Versions/small island developing states.json'.
# Copied '../00_API/regional energy organizations.json' to '../03_Output/01_Auto KGs/00_Current Versions/regional energy organizations.json'.
# Copied '../00_API/micro grids.json' to '../03_Output/01_Auto KGs/00_Current Versions/micro grids.json'.
# Copied '../00_API/concentrated solar power.json' to '../03_Output/01_Auto KGs/00_Current Versions/concentrated solar power.json'.
# Copied '../00_API/offshore renewable energy.json' to '../03_Output/01_Auto KGs/00_Current Versions/offshore renewable energy.json'.
# Copied '../00_API/women's economic empowerment.json' to '../03_Output/01_Auto KGs/00_Current Versions/women's economic empowerment.json'.
# Copied '../00_API/sovereign wealth funds.json' to '../03_Output/01_Auto KGs/00_Current Versions/sovereign wealth funds.json'.
# Copied '../00_API/green bonds.json' to '../03_Output/01_Auto KGs/00_Current Versions/green bonds.json'.
# Copied '../00_API/carbon pricing.json' to '../03_Output/01_Auto KGs/00_Current Versions/carbon pricing.json'.
# Copied '../00_API/climate resilience funds.json' to '../03_Output/01_Auto KGs/00_Current Versions/climate resilience funds.json'.
# Copied '../00_API/nature-based solutions.json' to '../03_Output/01_Auto KGs/00_Current Versions/nature-based solutions.json'.
# Copied '../00_API/theory of change.json' to '../03_Output/01_Auto KGs/00_Current Versions/theory of change.json'.
# Copied '../00_API/energy justice.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy justice.json'.
# Copied '../00_API/blockchain for energy trading.json' to '../03_Output/01_Auto KGs/00_Current Versions/blockchain for energy trading.json'.
# Copied '../00_API/carbon capture and storage.json' to '../03_Output/01_Auto KGs/00_Current Versions/carbon capture and storage.json'.
# Copied '../00_API/monitoring and evaluation frameworks.json' to '../03_Output/01_Auto KGs/00_Current Versions/monitoring and evaluation frameworks.json'.
# Copied '../00_API/biofuels.json' to '../03_Output/01_Auto KGs/00_Current Versions/biofuels.json'.
# Copied '../00_API/whole-of-society approach.json' to '../03_Output/01_Auto KGs/00_Current Versions/whole-of-society approach.json'.
# Copied '../00_API/energy democracy.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy democracy.json'.
# Copied '../00_API/integrated resource planning.json' to '../03_Output/01_Auto KGs/00_Current Versions/integrated resource planning.json'.
# Copied '../00_API/debt-for-nature swaps.json' to '../03_Output/01_Auto KGs/00_Current Versions/debt-for-nature swaps.json'.
# Copied '../00_API/heating and cooling.json' to '../03_Output/01_Auto KGs/00_Current Versions/heating and cooling.json'.
# Copied '../00_API/national digital transformation strategies.json' to '../03_Output/01_Auto KGs/00_Current Versions/national digital transformation strategies.json'.
# Copied '../00_API/risk insurance products.json' to '../03_Output/01_Auto KGs/00_Current Versions/risk insurance products.json'.
# Copied '../00_API/energy in crisis settings.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy in crisis settings.json'.
# Copied '../00_API/smart energy contracts.json' to '../03_Output/01_Auto KGs/00_Current Versions/smart energy contracts.json'.
# Copied '../00_API/clean cooking.json' to '../03_Output/01_Auto KGs/00_Current Versions/clean cooking.json'.
# Copied '../00_API/generative AI.json' to '../03_Output/01_Auto KGs/00_Current Versions/generative AI.json'.
# Copied '../00_API/digital cities.json' to '../03_Output/01_Auto KGs/00_Current Versions/digital cities.json'.
# Copied '../00_API/energy and development economics.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy and development economics.json'.
# Copied '../00_API/waster-to-energy solutions.json' to '../03_Output/01_Auto KGs/00_Current Versions/waster-to-energy solutions.json'.
# Copied '../00_API/energy markets.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy markets.json'.
# Copied '../00_API/time poverty.json' to '../03_Output/01_Auto KGs/00_Current Versions/time poverty.json'.
# Copied '../00_API/Solar For Health.json' to '../03_Output/01_Auto KGs/00_Current Versions/Solar For Health.json'.
# Copied '../00_API/gender mainstreaming.json' to '../03_Output/01_Auto KGs/00_Current Versions/gender mainstreaming.json'.
# Copied '../00_API/bioenergy.json' to '../03_Output/01_Auto KGs/00_Current Versions/bioenergy.json'.
# Copied '../00_API/mobile payment systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/mobile payment systems.json'.
# Copied '../00_API/energy transition roadmaps and plans.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy transition roadmaps and plans.json'.
# Copied '../00_API/electric mobility.json' to '../03_Output/01_Auto KGs/00_Current Versions/electric mobility.json'.
# Copied '../00_API/stakeholder engagement mechanisms.json' to '../03_Output/01_Auto KGs/00_Current Versions/stakeholder engagement mechanisms.json'.
# Copied '../00_API/battery storage.json' to '../03_Output/01_Auto KGs/00_Current Versions/battery storage.json'.
# Copied '../00_API/energy market liberalization policits.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy market liberalization policits.json'.
# Copied '../00_API/electrolysis.json' to '../03_Output/01_Auto KGs/00_Current Versions/electrolysis.json'.
# Copied '../00_API/carbon capture and utilization.json' to '../03_Output/01_Auto KGs/00_Current Versions/carbon capture and utilization.json'.
# Copied '../00_API/fossil fuel phase-out.json' to '../03_Output/01_Auto KGs/00_Current Versions/fossil fuel phase-out.json'.
# Copied '../00_API/energy regulatory frameworks.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy regulatory frameworks.json'.
# Copied '../00_API/undp accelerator labs.json' to '../03_Output/01_Auto KGs/00_Current Versions/undp accelerator labs.json'.
# Copied '../00_API/blue carbon.json' to '../03_Output/01_Auto KGs/00_Current Versions/blue carbon.json'.
# Copied '../00_API/solar home systems.json' to '../03_Output/01_Auto KGs/00_Current Versions/solar home systems.json'.
# Copied '../00_API/land stewardship agerements.json' to '../03_Output/01_Auto KGs/00_Current Versions/land stewardship agerements.json'.
# Copied '../00_API/gas turbine.json' to '../03_Output/01_Auto KGs/00_Current Versions/gas turbine.json'.
# Copied '../00_API/carbon neutrality.json' to '../03_Output/01_Auto KGs/00_Current Versions/carbon neutrality.json'.
# Copied '../00_API/undp country offices.json' to '../03_Output/01_Auto KGs/00_Current Versions/undp country offices.json'.
# Copied '../00_API/disaster warning networks.json' to '../03_Output/01_Auto KGs/00_Current Versions/disaster warning networks.json'.
# Copied '../00_API/energy cooperatives.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy cooperatives.json'.
# Copied '../00_API/benefit-sharing agreements.json' to '../03_Output/01_Auto KGs/00_Current Versions/benefit-sharing agreements.json'.
# Copied '../00_API/gasification.json' to '../03_Output/01_Auto KGs/00_Current Versions/gasification.json'.
# Copied '../00_API/energy data analytics.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy data analytics.json'.
# Copied '../00_API/energy value chain.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy value chain.json'.
# Copied '../00_API/resilient infrastructure.json' to '../03_Output/01_Auto KGs/00_Current Versions/resilient infrastructure.json'.
# Copied '../00_API/community-based energy resilience programs.json' to '../03_Output/01_Auto KGs/00_Current Versions/community-based energy resilience programs.json'.
# Copied '../00_API/energy poverty indices.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy poverty indices.json'.
# Copied '../00_API/intergenerational equity.json' to '../03_Output/01_Auto KGs/00_Current Versions/intergenerational equity.json'.
# Copied '../00_API/energy safety nets.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy safety nets.json'.
# Copied '../00_API/energy storage.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy storage.json'.
# Copied '../00_API/levelized cost of electricity.json' to '../03_Output/01_Auto KGs/00_Current Versions/levelized cost of electricity.json'.
# Copied '../00_API/biodigestion.json' to '../03_Output/01_Auto KGs/00_Current Versions/biodigestion.json'.
# Copied '../00_API/micro-finance.json' to '../03_Output/01_Auto KGs/00_Current Versions/micro-finance.json'.
# Copied '../00_API/foundational data infrastructure.json' to '../03_Output/01_Auto KGs/00_Current Versions/foundational data infrastructure.json'.
# Copied '../00_API/gender-sensitive electrification planning.json' to '../03_Output/01_Auto KGs/00_Current Versions/gender-sensitive electrification planning.json'.
# Copied '../00_API/medium small micro enterprises.json' to '../03_Output/01_Auto KGs/00_Current Versions/medium small micro enterprises.json'.
# Copied '../00_API/energy development practitioners.json' to '../03_Output/01_Auto KGs/00_Current Versions/energy development practitioners.json'.
# All files deleted in destination and copied from source successfully.

# %%
def flatten_all_relations(json_list, folder_path):
    for data in json_list:
        # Update metadata
        if "Entity" in data["metadata"]:
            entity_title = data["metadata"].pop("Entity")
            data["metadata"]["Entity Title"] = entity_title
            data["metadata"]["Entity Code"] = entity_title.lower()

        relations = data["knowledge graph"].pop("relations")
        sub_relations = data["knowledge graph"].pop("subelement_relations")

        all_relations = []
        entity_title = data["metadata"]["Entity Title"]

        for level, rel_list in relations.items():
            for relation in rel_list:
                if level == "level 1":
                    relation["Subject"] = entity_title
                all_relations.append(relation)

        for relations in sub_relations:
            all_relations.append(relations)

        data["knowledge graph"]["relations"] = all_relations

        # Update entities with metadata from files
        updated_entities = []
        for entity_name in data["knowledge graph"]["entities"]:
            entity_file_path = os.path.join(folder_path, f"{entity_name}.json")
            if os.path.isfile(entity_file_path):
                with open(entity_file_path, 'r') as entity_file:
                    entity_data = json.load(entity_file)
                    if "metadata" in entity_data:
                        metadata = entity_data["metadata"]
                        if "Entity" in metadata:
                            entity_title = metadata.pop("Entity")
                            metadata["Entity Title"] = entity_title
                            metadata["Entity Code"] = entity_title.lower()
                        updated_entities.append(metadata)
                    else:
                        updated_entities.append({"Entity Title": entity_name, "Entity Code": entity_name.lower(), "Error": "Metadata not found"})
            else:
                updated_entities.append({"Entity Title": entity_name, "Entity Code": entity_name.lower(), "Error": "File not found"})

        data["knowledge graph"]["entities"] = updated_entities

    return json_list

# %%
def flatten_all_relations(json_list, folder_path):
    for data in json_list:
        # Update metadata
        if "Entity" in data["metadata"]:
            entity_title = data["metadata"].pop("Entity")
            data["metadata"]["Entity Title"] = entity_title
            data["metadata"]["Entity Code"] = entity_title.lower()

        relations = data["knowledge graph"].pop("relations")
        sub_relations = data["knowledge graph"].pop("subelement_relations")

        all_relations = []
        entity_title = data["metadata"]["Entity Title"]

        for level, rel_list in relations.items():
            for relation in rel_list:
                if level == "level 1":
                    relation["Subject"] = entity_title
                all_relations.append(relation)

        for relation in sub_relations:
            all_relations.append(relation)

        data["knowledge graph"]["relations"] = all_relations

        # Update entities with metadata from files
        updated_entities = []
        # Add subelements if present
        #if "subelements" in data:
            #for subelement in data["subelements"]:
                #updated_entities.append(subelement)
            #del data["subelements"]

        # Process entities from knowledge graph
        for entity_name in data["knowledge graph"]["entities"]:
            entity_file_path = os.path.join(folder_path, f"{entity_name}.json")
            if os.path.isfile(entity_file_path):
                with open(entity_file_path, 'r') as entity_file:
                    entity_data = json.load(entity_file)
                    if "metadata" in entity_data:
                        metadata = entity_data["metadata"]
                        if "Entity" in metadata:
                            entity_title = metadata.pop("Entity")
                            metadata["Entity Title"] = entity_title
                            metadata["Entity Code"] = entity_title.lower()
                        updated_entities.append(metadata)
                    else:
                        updated_entities.append({"Entity Title": entity_name, "Entity Code": entity_name.lower(), "Error": "Metadata not found"})
            else:
                updated_entities.append({"Entity Title": entity_name, "Entity Code": entity_name.lower(), "Error": "File not found"})

        # Add objects from all relations
        for relation in all_relations:
            object_name = relation.get("Object")
            if object_name:
                entity_file_path = os.path.join(folder_path, f"{object_name}.json")
                if os.path.isfile(entity_file_path):
                    with open(entity_file_path, 'r') as entity_file:
                        entity_data = json.load(entity_file)
                        if "metadata" in entity_data:
                            metadata = entity_data["metadata"]
                            if "Entity" in metadata:
                                entity_title = metadata.pop("Entity")
                                metadata["Entity Title"] = entity_title
                                metadata["Entity Code"] = entity_title.lower()
                            updated_entities.append(metadata)
                        else:
                            updated_entities.append({"Entity Title": object_name, "Entity Code": object_name.lower(), "Error": "Metadata not found"})
                else:
                    updated_entities.append({"Entity Title": object_name, "Entity Code": object_name.lower(), "Error": "File not found"})

        data["knowledge graph"]["entities"] = updated_entities

    return json_list

# %%
import json
import os

def format_entity_title(title):
    articles = {"a", "an", "the", "and", "or", "but", "nor", "for", "so", "yet", "at", "by", "in", "of", "on", "to", "with"}
    words = title.split()
    formatted_words = [words[0].capitalize()]
    for word in words[1:]:
        formatted_words.append(word if word in articles else word.capitalize())
    return ' '.join(formatted_words)

def flatten_all_relations(json_list, folder_path):
    for data in json_list:
        # Update metadata
        if "Entity" in data["metadata"]:
            entity_title = data["metadata"].pop("Entity")
            formatted_entity_title = format_entity_title(entity_title)
            data["metadata"]["Entity Title"] = formatted_entity_title
            data["metadata"]["Entity Code"] = entity_title.lower()

        relations = data["knowledge graph"].pop("relations")
        sub_relations = data["knowledge graph"].pop("subelement_relations")
        relations['sub_relations'] = sub_relations

        all_relations = []
        entity_title = data["metadata"]["Entity Title"]
        entities_set = set(data["knowledge graph"]["entities"])  # To avoid duplicates

        for level, rel_list in relations.items():
            for relation in rel_list:
                if level == "level 1":
                    relation["Subject"] = entity_title
                else:
                    if "Sub-element" in relation:
                        relation["Subject"] = relation.pop("Sub-element").lower()
                    if "Parent" in relation:
                        relation["Object"] = relation.pop("Parent").lower()

                # Convert Subject and Object values to lower case
                if "Subject" in relation:
                    relation["Subject"] = relation["Subject"].lower()
                if "Object" in relation:
                    relation["Object"] = relation["Object"].lower()

                all_relations.append(relation)
                entities_set.add(relation["Object"])


        data["knowledge graph"]["relations"] = all_relations

        # Update entities with metadata from files
        updated_entities = []
        for entity_name in entities_set:
            entity_file_path = os.path.join(folder_path, f"{entity_name}.json")
            if os.path.isfile(entity_file_path):
                with open(entity_file_path, 'r') as entity_file:
                    entity_data = json.load(entity_file)
                    if "metadata" in entity_data:
                        metadata = entity_data["metadata"]
                        if "Entity" in metadata:
                            entity_title = metadata.pop("Entity")
                            metadata["Entity Title"] = format_entity_title(entity_title)
                            metadata["Entity Code"] = entity_title.lower()
                        updated_entities.append(metadata)
                    else:
                        updated_entities.append({"Entity Title": format_entity_title(entity_name), "Entity Code": entity_name.lower(), "Error": "Metadata not found"})
            else:
                updated_entities.append({"Entity Title": format_entity_title(entity_name), "Entity Code": entity_name.lower(), "Category": "Missing"})

        data["knowledge graph"]["entities"] = updated_entities

    return json_list

# %%
with open('../03_Output/01_Auto KGs/02_Replaced Relations/Nested Relations.json', "r") as file:
    data = file.read()
    kg = json.loads(data)
    file.close()

# %%
folder_path = '../03_Output/01_Auto KGs/00_Current Versions/'
kg_new = flatten_all_relations(kg, folder_path)

# %%
kg_new[1]
# Out:
# {'metadata': {'Description': 'Refers to the interconnected network of individuals, organizations, and systems that share and utilize data.',
#   'Category': 'Technology',
#   'Tags': ['Data Sharing', 'Data Collaboration', 'Data Governance'],
#   'Dimension': 'Technology',
#   'Acronym': None,
#   'Importance': 2.0,
#   'Synonyms': None,
#   'Entity Title': 'Data Ecosystems',
#   'Entity Code': 'data ecosystems'},
#  'knowledge graph': {'entities': [{'Entity Title': 'Digital Transformation',
#     'Entity Code': 'digital transformation',
#     'Category': 'Missing'},
#    {'Entity Title': 'Government Agencies',
#     'Entity Code': 'government agencies',
#     'Category': 'Missing'},
#    {'Description': 'Markets where electricity, natural gas, and other energy commodities are bought and sold.',
#     'Category': 'Economic',
#     'Tags': ['Energy', 'Markets', 'Commodities'],
#     'Dimension': 'Economic',
#     'Acronym': None,
#     'Importance': 4.0,
#     'Synonyms': ['energy startups',
#      'energy access',
#      'energy audits',
#      'energy market',
#      'energy market monopoly'],
#     'Entity Title': 'Energy Markets',
#     'Entity Code': 'energy markets'},
#    {'Entity Title': 'Research and Development',
#     'Entity Code': 'research and development',
#     'Category': 'Missing'},
#    {'Entity Title': 'Research Institutions',
#     'Entity Code': 'research institutions',
#     'Category': 'Missing'},
#    {'Entity Title': 'Un Sustainable Development Goals',
#     'Entity Code': 'un sustainable development goals',
#     'Category': 'Missing'},
#    {'Description': 'Agencies that promote and support the development and use of renewable energy sources.',
#     'Category': 'Organization',
#     'Tags': ['Policy', 'Technology', 'Economic'],
#     'Dimension': 'Policy',
#     'Acronym': None,
#     'Importance': 3.0,
#     'Synonyms': ['renewable energy projects',
#      'renewable energy generation',
#      'renewable energy mapping',
#      'renewable energy access',
#      'renewable energy research',
#      'renewable energy technologies',
#      'renewable energy capacity',
#      'renewable energy sources',
#      'international renewable energy agency',
#      'renewable energy transition',
#      'renewable energy solutions',
#      'renewable energy deployment',
#      'renewable energy investments',
#      'renewable energy market',
#      'renewable energy companies',
#      'renewable energy adoption',
#      'renewable energy providers',
#      'renewable energy standards',
#      'renewable energy incentives',
#      'renewable energy performance',
#      'renewable energy developers',
#      'renewable energy solution',
#      'renewable energy goals',
#      'renewable energy experts'],
#     'Entity Title': 'Renewable Energy Agencies',
#     'Entity Code': 'renewable energy agencies'},
#    {'Description': 'Refers to the interconnected network of individuals, organizations, and systems that share and utilize data.',
#     'Category': 'Technology',
#     'Tags': ['Data Sharing', 'Data Collaboration', 'Data Governance'],
#     'Dimension': 'Technology',
#     'Acronym': None,
#     'Importance': 2.0,
#     'Synonyms': None,
#     'Entity Title': 'Data Ecosystems',
#     'Entity Code': 'data ecosystems'},
#    {'Description': 'Protection of data from unauthorized access and ensuring its confidentiality and integrity.',
#     'Category': 'Technology',
#     'Tags': ['Data', 'Privacy', 'Security'],
#     'Dimension': 'Technology',
#     'Acronym': None,
#     'Importance': 3.0,
#     'Synonyms': None,
#     'Entity Title': 'Data Privacy and Security',
#     'Entity Code': 'data privacy and security'},
#    {'Entity Title': 'Artificial Intelligence',
#     'Entity Code': 'artificial intelligence',
#     'Category': 'Missing'},
#    {'Entity Title': 'Industries',
#     'Entity Code': 'industries',
#     'Category': 'Missing'},
#    {'Description': 'The use of less energy to provide the same level of output or service, resulting in reduced energy consumption, cost savings, and environmental benefits.',
#     'Category': 'Technology',
#     'Tags': ['Energy Conservation', 'Energy Management', 'Sustainability'],
#     'Dimension': 'Technology',
#     'Acronym': None,
#     'Importance': 4.0,
#     'Synonyms': ['energy efficiency policy',
#      'energy efficiency programs',
#      'energy efficiency goals',
#      'energy efficiency performance',
#      'energy efficiency initiatives',
#      'energy efficiency measures',
#      'energy efficiency improvements',
#      'energy efficiency targets'],
#     'Entity Title': 'Energy Efficiency',
#     'Entity Code': 'energy efficiency'},
#    {'Description': 'The analysis of energy data to gain insights and inform decision-making in the energy sector.',
#     'Category': 'Technology',
#     'Tags': ['Data-driven Insights', 'Energy Efficiency'],
#     'Dimension': 'Technology',
#     'Acronym': None,
#     'Importance': 3.0,
#     'Synonyms': ['energy data management',
#      'energy market analysis',
#      'data analytics',
#      'energy analysts'],
#     'Entity Title': 'Energy Data Analytics',
#     'Entity Code': 'energy data analytics'},
#    {'Entity Title': 'Sustainable Energy Projects',
#     'Entity Code': 'sustainable energy projects',
#     'Category': 'Missing'},
#    {'Description': 'The process of capturing and storing energy for later use.',
#     'Category': 'Technology',
#     'Tags': ['Renewable Energy', 'Grid Stability', 'Battery Technology'],
#     'Dimension': 'Technology',
#     'Acronym': None,
#     'Importance': 4.0,
#     'Synonyms': ['energy waste',
#      'energy storage capacity',
#      'energy savings',
#      'energy data',
#      'energy storage solutions',
#      'energy storage policy',
#      'energy surveys'],
#     'Entity Title': 'Energy Storage',
#     'Entity Code': 'energy storage'},
#    {'Description': 'Repositories that store and manage energy-related data.',
#     'Category': 'Technology',
#     'Tags': ['Data', 'Energy', 'Repositories'],
#     'Dimension': 'Technology',
#     'Acronym': None,
#     'Importance': 3.0,
#     'Synonyms': ['energy data platform'],
#     'Entity Title': 'Energy Data Repositories',
#     'Entity Code': 'energy data repositories'}],
#   'sub-elements': ['data sharing',
#    'data governance',
#    'data analytics',
#    'data visualization',
#    'data privacy'],
#   'relations': [{'Relation': 'addresses',
#     'Object': 'energy data analytics',
#     'Description': 'Data ecosystems address the challenges of energy data management to enable effective analysis and decision-making in the sustainable energy sector.',
#     'Importance': 4,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'employs',
#     'Object': 'artificial intelligence',
#     'Description': 'Data ecosystems employ artificial intelligence technologies to analyze energy data and derive insights for sustainable energy planning.',
#     'Importance': 3,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'collaborates_with',
#     'Object': 'research institutions',
#     'Description': 'Data ecosystems collaborate with research institutions to enhance data-driven research and innovation in the sustainable energy field.',
#     'Importance': 4,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'supports',
#     'Object': 'energy markets',
#     'Description': 'Data ecosystems support energy startups by providing access to data and resources for developing innovative sustainable energy solutions.',
#     'Importance': 3,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'administers',
#     'Object': 'energy data repositories',
#     'Description': 'Data ecosystems administer an energy data platform to facilitate data sharing and collaboration among stakeholders in the sustainable energy sector.',
#     'Importance': 4,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'measures',
#     'Object': 'energy efficiency',
#     'Description': 'Data ecosystems measure energy efficiency to assess the impact of sustainable energy initiatives and identify areas for improvement.',
#     'Importance': 3,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'aligns_with',
#     'Object': 'un sustainable development goals',
#     'Description': 'Data ecosystems align with the UN Sustainable Development Goals to contribute to the achievement of sustainable energy targets.',
#     'Importance': 4,
#     'Subject': 'data ecosystems'},
#    {'Relation': 'an_instance_of',
#     'Object': 'digital transformation',
#     'Description': 'Data ecosystems are an instance of digital transformation in the sustainable energy sector, leveraging data-driven technologies for improved energy management.',
#     'Importance': 4,
#     'Subject': 'data ecosystems'},
#    {'Subject': 'energy data analytics',
#     'Relation': 'implements',
#     'Object': 'energy efficiency',
#     'Description': 'Energy data analytics implements the Energy Efficiency Policy to optimize energy consumption and reduce waste.',
#     'Importance': 4},
#    {'Subject': 'energy data analytics',
#     'Relation': 'funds',
#     'Object': 'research and development',
#     'Description': 'Energy data analytics funds research and development projects to advance sustainable energy technologies and practices.',
#     'Importance': 3},
#    {'Subject': 'energy markets',
#     'Relation': 'addresses',
#     'Object': 'energy markets',
#     'Description': 'Energy markets address the issue of energy access by ensuring the availability and affordability of energy sources for all segments of society.',
#     'Importance': 4},
#    {'Subject': 'energy markets',
#     'Relation': 'collaborates_with',
#     'Object': 'government agencies',
#     'Description': 'Energy markets collaborate with government agencies to develop and implement policies and regulations that promote a sustainable and efficient energy sector.',
#     'Importance': 4},
#    {'Subject': 'energy data repositories',
#     'Relation': 'implements',
#     'Object': 'data privacy and security',
#     'Description': 'Energy data repositories implement data privacy and security measures to protect sensitive information.',
#     'Importance': 4},
#    {'Subject': 'energy data repositories',
#     'Relation': 'funds',
#     'Object': 'data privacy and security',
#     'Description': 'Energy data repositories provide funding for initiatives related to data privacy and security.',
#     'Importance': 3},
#    {'Subject': 'energy efficiency',
#     'Relation': 'addresses',
#     'Object': 'energy storage',
#     'Description': 'Energy efficiency measures address energy waste by promoting the use of energy-efficient technologies and practices.',
#     'Importance': 4},
#    {'Subject': 'energy efficiency',
#     'Relation': 'collaborates_with',
#     'Object': 'industries',
#     'Description': 'Energy efficiency collaborates with industries to develop and implement energy-saving measures and technologies.',
#     'Importance': 4},
#    {'Subject': 'energy efficiency',
#     'Relation': 'addresses',
#     'Object': 'energy storage',
#     'Description': 'Energy efficiency measures address energy waste by promoting the use of energy-efficient technologies and practices.',
#     'Importance': 4},
#    {'Subject': 'renewable energy agencies',
#     'Relation': 'employs',
#     'Object': 'renewable energy agencies',
#     'Description': 'Renewable energy agencies employ experts in the field of renewable energy to drive innovation and promote the adoption of clean energy technologies.',
#     'Importance': 4},
#    {'Subject': 'energy markets',
#     'Relation': 'addresses',
#     'Object': 'energy markets',
#     'Description': 'Energy markets address the issue of energy access by ensuring the availability and affordability of energy sources for all segments of society.',
#     'Importance': 4},
#    {'Subject': 'climate change scenario analysis',
#     'Relation': 'implements',
#     'Object': 'sustainable energy projects',
#     'Description': 'Climate change scenario analysis implements sustainable energy projects to mitigate the impacts of climate change.',
#     'Importance': 4},
#    {'Relation': 'is a sub-element of',
#     'Description': 'Data sharing is a key component of data ecosystems, enabling the exchange and collaboration of data between different stakeholders. It promotes transparency, interoperability, and the creation of new insights and knowledge.',
#     'Importance': 4,
#     'Subject': 'data sharing',
#     'Object': 'data ecosystems'},
#    {'Relation': 'is a sub-element of',
#     'Description': 'Data governance is essential for the effective management and control of data within data ecosystems. It involves defining policies, procedures, and responsibilities to ensure data quality, security, privacy, and compliance.',
#     'Importance': 4,
#     'Subject': 'data governance',
#     'Object': 'data ecosystems'},
#    {'Relation': 'is a sub-element of',
#     'Description': 'Data analytics plays a crucial role in data ecosystems by extracting valuable insights and patterns from large volumes of data. It involves the use of statistical and computational techniques to analyze and interpret data for decision-making and problem-solving.',
#     'Importance': 4,
#     'Subject': 'data analytics',
#     'Object': 'data ecosystems'},
#    {'Relation': 'is a sub-element of',
#     'Description': 'Data visualization is an important aspect of data ecosystems as it enables the representation of data in visual formats such as charts, graphs, and maps. It helps in understanding complex data patterns, trends, and relationships.',
#     'Importance': 3,
#     'Subject': 'data visualization',
#     'Object': 'data ecosystems'},
#    {'Relation': 'is a sub-element of',
#     'Description': 'Data privacy is a critical consideration in data ecosystems to protect the confidentiality and integrity of personal and sensitive data. It involves implementing measures and policies to ensure that data is collected, stored, and processed in a secure and ethical manner.',
#     'Importance': 4,
#     'Subject': 'data privacy',
#     'Object': 'data ecosystems'}]}}

# %%
def update_api_folder(kg_new, api_folder_path):
    # Delete all files in the API folder
    for filename in os.listdir(api_folder_path):
        file_path = os.path.join(api_folder_path, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)

    # Add new files to the API folder
    for item in kg_new:
        name = item['metadata']['Entity Code']
        json_ = json.dumps(item, indent=2)
        with open(os.path.join(api_folder_path, name + '.json'), 'w') as file:
            file.write(json_)

# %%
api_folder_path = '../00_API/'
update_api_folder(kg_new, api_folder_path)
